# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = f"{url}api-key={nyt_api_key}&fq={filter_query}&sort={sort}&fl={field_list}&begin_date={begin_date}&end_date={end_date}"

# %%
# Create an empty list to store the reviews
reviews = []

# loop through pages 0-19
for page in range(0, 19):

    # create query with a page number
    # API results show 10 articles at a time
    final_url = f"{query_url}&page={str(page)}"
    
    
    # Make a "GET" request and retrieve the JSON
    articles = requests.get(query_url).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        # loop through the reviews["response"]["docs"] and append each review to the list
        for article in articles["response"]["docs"]:
            reviews.append(article)

        # Print the page that was just retrieved
        print(f"The acticle page number {page} was retrieved")
    except:
    #     # Print the page number that had no results then break from the loop
        print("Page number has no results")
        break
# Out:
# The acticle page number 0 was retrieved
# The acticle page number 1 was retrieved
# The acticle page number 2 was retrieved
# The acticle page number 3 was retrieved
# The acticle page number 4 was retrieved
# The acticle page number 5 was retrieved
# The acticle page number 6 was retrieved
# The acticle page number 7 was retrieved
# The acticle page number 8 was retrieved
# The acticle page number 9 was retrieved
# The acticle page number 10 was retrieved
# The acticle page number 11 was retrieved
# The acticle page number 12 was retrieved
# The acticle page number 13 was retrieved
# The acticle page number 14 was retrieved
# The acticle page number 15 was retrieved
# The acticle page number 16 was retrieved
# The acticle page number 17 was retrieved
# The acticle page number 18 was retrieved

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
json.dumps(reviews[0:5], indent=4)
# Out:
# '[\n    {\n        "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",\n        "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",\n        "source": "The New York Times",\n        "headline": {\n            "main": "\\u2018The Attachment Diaries\\u2019 Review: Love, Sick",\n            "kicker": null,\n            "content_kicker": null,\n            "print_headline": "The Attachment Diaries",\n            "name": null,\n            "seo": null,\n            "sub": null\n        },\n        "keywords": [\n            {\n                "name": "subject",\n                "value": "Movies",\n                "rank": 1,\n                "major": "N"\n            },\n            {\n                "name": "creative_works",\n                "value": "The Attachment Diaries (Movie)",\n                "rank": 2,\n                "major": "N"\n            },\n            {\n                "name": "persons",\n                "value": "Diment, Valentin Javier",\n                "rank": 3,\n                "major": "N"\n            }\n        ],\n        "pub_date": "2023-05-25T11:00:03+0000",\n        "byline": {\n            "original": "By Jeannette Catsoulis",\n            "person": [\n                {\n                    "firstname": "Jeannette",\n                    "middlename": null,\n                    "lastname": "Catsoulis",\n                    "qualifier": null,\n                    "title": null,\n                    "role": "reported",\n                    "organization": "",\n                    "rank": 1\n                }\n            ],\n            "organization": null\n        },\n        "word_count": 295\n    },\n    {\n        "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",\n        "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",\n        "source": "The New York Times",\n        "headline": {\n            "main": "Review: \\u2018What\\u2019s Love Got to Do With It?\\u2019 Probably a Lot",\n            "kicker": null,\n            "content_kicker": null,\n            "print_headline": "What\\u2019s Love Got to Do With It?",\n            "name": null,\n            "seo": null,\n            "sub": null\n        },\n        "keywords": [\n            {\n                "name": "subject",\n                "value": "Movies",\n                "rank": 1,\n                "major": "N"\n            },\n            {\n                "name": "persons",\n                "value": "Kapur, Shekhar",\n                "rank": 2,\n                "major": "N"\n            },\n            {\n                "name": "persons",\n                "value": "James, Lily",\n                "rank": 3,\n                "major": "N"\n            },\n            {\n                "name": "persons",\n                "value": "Azmi, Shabana",\n                "rank": 4,\n                "major": "N"\n            },\n            {\n                "name": "persons",\n                "value": "Thompson, Emma",\n                "rank": 5,\n                "major": "N"\n            }\n        ],\n        "pub_date": "2023-05-04T17:16:45+0000",\n        "byline": {\n            "original": "By Jeannette Catsoulis",\n            "person": [\n                {\n                    "firstname": "Jeannette",\n                    "middlename": null,\n                    "lastname": "Catsoulis",\n                    "qualifier": null,\n                    "title": null,\n                    "role": "reported",\n                    "organization": "",\n                    "rank": 1\n                }\n            ],\n            "organization": null\n        },\n        "word_count": 287\n    },\n    {\n        "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",\n        "snippet": "Reli ...

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_df = pd.json_normalize(reviews)
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 185  https://www.nytimes.com/2023/04/13/movies/one-...
# 186  https://www.nytimes.com/2023/04/13/movies/the-...
# 187  https://www.nytimes.com/2023/03/30/movies/a-th...
# 188  https://www.nytimes.com/2023/02/09/movies/your...
# 189  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 185  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 186  There’s not much Lennon music heard in this do...  The New York Times
# 187  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
# 188  This humdrum Netflix romantic comedy features ...  The New York Times
# 189  To combat the overdose crisis, a group that in...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 185  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 186  [{'name': 'subject', 'value': 'Documentary Fil...
# 187  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 188  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 189  [{'name': 'subject', 'value': 'Documentary Fil...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 185  2023-04-13T11:00:06+0000         320
# 186  2023-04-13T11:00:03+0000         327
# 187  2023-03-30T18:53:42+0000         971
# 188  2023-02-10T00:00:05+0000         569
# 189  2023-02-02T12:00:11+0000         306
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 185     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 186  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 187  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
# 188           ‘Your Place or Mine’ Review: Try Neither            None
# 189  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#     headline.content_kicker                  headline.print_headline  \
# 0                      None                   The Attachment Diaries
# 1                      None           What’s Love Got to Do With It?
# 2                      None                     You Can Live Forever
# 3                      None               A Tourist’s  Guide to Love
# 4                      None   Intoxicating Love With a Sobering Turn
# ..                      ...                                      ...
# 185                    None                           One True Loves
# 186                    None          The Lost Weekend:  A Love Story
# 187                    None  An Unbending Will Meets a Shifting City
# 188                    None         They Have a Humdrum Kind of Love
# 189                    None             Love in the Time Of Fentanyl
#
#     headline.name headline.seo headline.sub           byline.original  \
# 0            None         None         None    By Jeannette Catsoulis
# 1            None         None         None    By Jeannette Catsoulis
# 2            None         None         None  By Elisabeth Vincentelli
# 3            None         None         None  By Elisabeth Vincentelli
# 4            None         None         None         By Manohla Dargis
# ..            ...          ...          ...                       ...
# 185          None         None         None             By Brandon Yu
# 186          None         None         None            By Glenn Kenny
# 187          None         None         None         By Manohla Dargis
# 188          None         None         None          By Amy Nicholson
# 189          None         None         None     By Concepción de León
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 185  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 186  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 187  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 188  [{'firstname': 'Amy', 'middlename': None, 'las...                None
# 189  [{'firstname': 'Concepción', 'middlename': Non...                None
#
# [190 rows x 16 columns]

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
reviews_df['title'] = reviews_df['headline.main'].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])

# %%
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 185  https://www.nytimes.com/2023/04/13/movies/one-...
# 186  https://www.nytimes.com/2023/04/13/movies/the-...
# 187  https://www.nytimes.com/2023/03/30/movies/a-th...
# 188  https://www.nytimes.com/2023/02/09/movies/your...
# 189  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 185  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 186  There’s not much Lennon music heard in this do...  The New York Times
# 187  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
# 188  This humdrum Netflix romantic comedy features ...  The New York Times
# 189  To combat the overdose crisis, a group that in...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 185  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 186  [{'name': 'subject', 'value': 'Documentary Fil...
# 187  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 188  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 189  [{'name': 'subject', 'value': 'Documentary Fil...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 185  2023-04-13T11:00:06+0000         320
# 186  2023-04-13T11:00:03+0000         327
# 187  2023-03-30T18:53:42+0000         971
# 188  2023-02-10T00:00:05+0000         569
# 189  2023-02-02T12:00:11+0000         306
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 185     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 186  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 187  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
# 188           ‘Your Place or Mine’ Review: Try Neither            None
# 189  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#     headline.content_kicker                  headline.print_headline  \
# 0                      None                   The Attachment Diaries
# 1                      None           What’s Love Got to Do With It?
# 2                      None                     You Can Live Forever
# 3                      None               A Tourist’s  Guide to Love
# 4                      None   Intoxicating Love With a Sobering Turn
# ..                      ...                                      ...
# 185                    None                           One True Loves
# 186                    None          The Lost Weekend:  A Love Story
# 187                    None  An Unbending Will Meets a Shifting City
# 188                    None         They Have a Humdrum Kind of Love
# 189                    None             Love in the Time Of Fentanyl
#
#     headline.name headline.seo headline.sub           byline.original  \
# 0            None         None         None    By Jeannette Catsoulis
# 1            None         None         None    By Jeannette Catsoulis
# 2            None         None         None  By Elisabeth Vincentelli
# 3            None         None         None  By Elisabeth Vincentelli
# 4            None         None         None         By Manohla Dargis
# ..            ...          ...          ...                       ...
# 185          None         None         None             By Brandon Yu
# 186          None         None         None            By Glenn Kenny
# 187          None         None         None         By Manohla Dargis
# 188          None         None         None          By Amy Nicholson
# 189          None         None         None     By Concepción de León
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 185  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 186  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 187  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 188  [{'firstname': 'Amy', 'middlename': None, 'las...                None
# 189  [{'firstname': 'Concepción', 'middlename': Non...                None
#
#                                              title
# 0                           The Attachment Diaries
# 1    What’s Love Got to Do With It?’ Probably a Lo
# 2                             You Can Live Forever
# 3                        A Tourist’s Guide to Love
# 4                          Other People’s Children
# ..                                             ...
# 185                                 One True Loves
# 186                 The Lost Weekend: A Love Story
# 187                             A Thousand and One
# 188                             Your Place or Mine
# 189                   Love in the Time of Fentanyl
#
# [190 rows x 17 columns]

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_df['keywords'] = reviews_df['keywords'].apply(extract_keywords)

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
movie_list = reviews_df['title'].to_list()
movie_list
# Out:
# ['The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl']

# %% [markdown]
# ### Access The Movie Database API

# %%
tmdb_api_key = '35ea1d408e4b2825718163d46798db82'

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
# tmdb_api_key = '35ea1d408e4b2825718163d46798db82'
# query = movie_list

tmdb_key_string = "&api_key=" + tmdb_api_key
# request_url = f"{url}?query={query}{tmdb_key_string}"


# #Build the URL
# response = requests.get(request_url)

# #movie_query_url = requests.get(f"{url}tmdb_key_string&mi={movie_id}api_key={tmdb_api_key}")
# if response.status_code == 200:
#     print("Success")
#     print(response.json())
# else:
#     print('shoot')

# %%
# Create an empty list to store the results
movie_results = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_count = 1

# Loop through the titles
for title in movie_list:

    # Check if we need to sleep before making a request
    if request_count % 50 == 0:
        time.sleep(1)

    # Add 1 to the request counter
    request_count += 1
    
    # Perform a "GET" request for The Movie Database
    articles = requests.get(url+title+tmdb_key_string).json()
    
    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    try:
        # Get movie id
        movie_id = articles["results"][0]['id']
        

        # Make a request for a the full movie details
        query_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"
        #movie_detail = requests.get(movie_id).json()
        

        # Execute "GET" request with url
        articles = requests.get(query_url).json()
        
        
        # Extract the genre names into a list
        genres = [genre['name'] for genre in articles['genres']]


        # Extract the spoken_languages' English name into a list
        spoken_languages = [language['english_name'] for language in articles['spoken_languages']]


        # Extract the production_countries' name into a list
        production_countries = [country['name'] for country in articles['production_countries']]


        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        movie_results.append({
            'id' : movie_id,
            'title' : title, 
            'genres' : genres,
            'spoken_languages' : spoken_languages,
            'production_countries' : production_countries
        })

        
        # Print out the title that was found
        print(f'The {title} was found.')

    except:
        print(f'No movie with the title of {title} was found. ')
# Out:
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.
# The The Attachment Diaries was found.
# No movie with the title of What’s Love Got to Do With It?’ Probably a Lo was found.
# The You Can Live Forever was found.
# The A Tourist’s Guide to Love was found.
# The Other People’s Children was found.
# The One True Loves was found.
# The The Lost Weekend: A Love Story was found.
# The A Thousand and One was found.
# The Your Place or Mine was found.
# The Love in the Time of Fentanyl was found.

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
json.dumps(movie_results[0:5], indent=4)
# Out:
# '[\n    {\n        "id": 743040,\n        "title": "The Attachment Diaries",\n        "genres": [\n            "Drama",\n            "Mystery",\n            "Thriller",\n            "Horror"\n        ],\n        "spoken_languages": [\n            "Spanish"\n        ],\n        "production_countries": [\n            "Argentina"\n        ]\n    },\n    {\n        "id": 887580,\n        "title": "You Can Live Forever",\n        "genres": [\n            "Drama",\n            "Romance"\n        ],\n        "spoken_languages": [\n            "English",\n            "French"\n        ],\n        "production_countries": [\n            "Canada",\n            "United States of America"\n        ]\n    },\n    {\n        "id": 813726,\n        "title": "A Tourist\\u2019s Guide to Love",\n        "genres": [\n            "Romance",\n            "Comedy"\n        ],\n        "spoken_languages": [\n            "English",\n            "Vietnamese"\n        ],\n        "production_countries": [\n            "United States of America"\n        ]\n    },\n    {\n        "id": 803694,\n        "title": "Other People\\u2019s Children",\n        "genres": [\n            "Drama",\n            "Comedy"\n        ],\n        "spoken_languages": [\n            "French",\n            "English"\n        ],\n        "production_countries": [\n            "France"\n        ]\n    },\n    {\n        "id": 846961,\n        "title": "One True Loves",\n        "genres": [\n            "Romance",\n            "Comedy",\n            "Drama"\n        ],\n        "spoken_languages": [\n            "English",\n            "Spanish"\n        ],\n        "production_countries": [\n            "Czech Republic",\n            "United States of America"\n        ]\n    }\n]'

# %%
# Convert the results to a DataFrame
movie_results_df = pd.json_normalize(movie_results)
movie_results_df
# Out:
#          id                           title  \
# 0    743040          The Attachment Diaries
# 1    887580            You Can Live Forever
# 2    813726       A Tourist’s Guide to Love
# 3    803694         Other People’s Children
# 4    846961                  One True Loves
# ..      ...                             ...
# 166  846961                  One True Loves
# 167  965042  The Lost Weekend: A Love Story
# 168  855263              A Thousand and One
# 169  703451              Your Place or Mine
# 170  976653    Love in the Time of Fentanyl
#
#                                  genres                spoken_languages  \
# 0    [Drama, Mystery, Thriller, Horror]                       [Spanish]
# 1                      [Drama, Romance]               [English, French]
# 2                     [Romance, Comedy]           [English, Vietnamese]
# 3                       [Drama, Comedy]               [French, English]
# 4              [Romance, Comedy, Drama]              [English, Spanish]
# ..                                  ...                             ...
# 166            [Romance, Comedy, Drama]              [English, Spanish]
# 167                       [Documentary]                       [English]
# 168                      [Drama, Crime]  [English, Spanish, Portuguese]
# 169                   [Romance, Comedy]                       [English]
# 170                       [Documentary]                       [English]
#
#                            production_countries
# 0                                   [Argentina]
# 1            [Canada, United States of America]
# 2                    [United States of America]
# 3                                      [France]
# 4    [Czech Republic, United States of America]
# ..                                          ...
# 166  [Czech Republic, United States of America]
# 167                  [United States of America]
# 168                  [United States of America]
# 169                  [United States of America]
# 170          [Canada, United States of America]
#
# [171 rows x 5 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_df = pd.merge(reviews_df, movie_results_df, on='title', how='inner')
merged_df
# Out:
#                                                 web_url  \
# 0     https://www.nytimes.com/2023/05/25/movies/the-...
# 1     https://www.nytimes.com/2023/05/25/movies/the-...
# 2     https://www.nytimes.com/2023/05/25/movies/the-...
# 3     https://www.nytimes.com/2023/05/25/movies/the-...
# 4     https://www.nytimes.com/2023/05/25/movies/the-...
# ...                                                 ...
# 3244  https://www.nytimes.com/2023/02/02/movies/love...
# 3245  https://www.nytimes.com/2023/02/02/movies/love...
# 3246  https://www.nytimes.com/2023/02/02/movies/love...
# 3247  https://www.nytimes.com/2023/02/02/movies/love...
# 3248  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                 snippet              source  \
# 0     A gynecologist and her patient form a horrifyi...  The New York Times
# 1     A gynecologist and her patient form a horrifyi...  The New York Times
# 2     A gynecologist and her patient form a horrifyi...  The New York Times
# 3     A gynecologist and her patient form a horrifyi...  The New York Times
# 4     A gynecologist and her patient form a horrifyi...  The New York Times
# ...                                                 ...                 ...
# 3244  To combat the overdose crisis, a group that in...  The New York Times
# 3245  To combat the overdose crisis, a group that in...  The New York Times
# 3246  To combat the overdose crisis, a group that in...  The New York Times
# 3247  To combat the overdose crisis, a group that in...  The New York Times
# 3248  To combat the overdose crisis, a group that in...  The New York Times
#
#                                                keywords  \
# 0     subject: Movies;creative_works: The Attachment...
# 1     subject: Movies;creative_works: The Attachment...
# 2     subject: Movies;creative_works: The Attachment...
# 3     subject: Movies;creative_works: The Attachment...
# 4     subject: Movies;creative_works: The Attachment...
# ...                                                 ...
# 3244  subject: Documentary Films and Programs;subjec...
# 3245  subject: Documentary Films and Programs;subjec...
# 3246  subject: Documentary Films and Programs;subjec...
# 3247  subject: Documentary Films and Programs;subjec...
# 3248  subject: Documentary Films and Programs;subjec...
#
#                       pub_date  word_count  \
# 0     2023-05-25T11:00:03+0000         295
# 1     2023-05-25T11:00:03+0000         295
# 2     2023-05-25T11:00:03+0000         295
# 3     2023-05-25T11:00:03+0000         295
# 4     2023-05-25T11:00:03+0000         295
# ...                        ...         ...
# 3244  2023-02-02T12:00:11+0000         306
# 3245  2023-02-02T12:00:11+0000         306
# 3246  2023-02-02T12:00:11+0000         306
# 3247  2023-02-02T12:00:11+0000         306
# 3248  2023-02-02T12:00:11+0000         306
#
#                                           headline.main headline.kicker  \
# 0           ‘The Attachment Diaries’ Review: Love, Sick            None
# 1           ‘The Attachment Diaries’ Review: Love, Sick            None
# 2           ‘The Attachment Diaries’ Review: Love, Sick            None
# 3           ‘The Attachment Diaries’ Review: Love, Sick            None
# 4           ‘The Attachment Diaries’ Review: Love, Sick            None
# ...                                                 ...             ...
# 3244  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3245  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3246  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3247  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3248  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#      headline.content_kicker       headline.print_headline  ... headline.seo  \
# 0                       None        The Attachment Diaries  ...         None
# 1                       None        The Attachment Diaries  ...         None
# 2                       None        The Attachment Diaries  ...         None
# 3                       None        The Attachment Diaries  ...         None
# 4                       None        The Attachment Diaries  ...         None
# ...                      ...                           ...  ...          ...
# 3244                    None  Love in the Time Of Fentanyl  ...         None
# 3245                    None  Love in the Time Of Fentanyl  ...         None
# 3246                    None  Love in the Time Of Fentanyl  ...         None
# 3247                    None  Love in the Time Of Fentanyl  ...         None
# 3248                    None  Love in the Time Of Fentanyl  ...         None
#
#      headline.sub         byline.original  \
# 0            None  By Jeannette Catsoulis
# 1            None  By Jeannette Catsoulis
# 2            None  By Jeannette Catsoulis
# 3            None  By Jeannette Catsoulis
# 4            None  By Jeannette Catsoulis
# ...           ...                     ...
# 3244         None   By Concepción de León
# 3245         None   By Concepción de León
# 3246         None   By Concepción de León
# 3247         None   By Concepción de León
# 3248         None   By Concepción de León
#
#                                           byline.person byline.organization  \
# 0     [{'firstname': 'Jeannette', 'middlename': None...                None
# 1     [{'firstname': 'Jeannette', 'middlename': None...                None
# 2     [{'firstname': 'Jeannette', 'middlename': None...                None
# 3     [{'firstname': 'Jeannette', 'middlename': None...                None
# 4     [{'firstname': 'Jeannette', 'middlename': None...                None
# ...                                                 ...                 ...
# 3244  [{'firstname': 'Concepción', 'middlename': Non...                None
# 3245  [{'firstname': 'Concepción', 'middlename': Non...                None
# 3246  [{'firstname': 'Concepción', 'middlename': Non...                None
# 3247  [{'firstname': 'Concepción', 'middlename': Non...                None
# 3248  [{'firstname': 'Concepción', 'middlename': Non...                None
#
#                              title      id  \
# 0           The Attachment Diaries  743040
# 1           The Attachment Diaries  743040
# 2           The Attachment Diaries  743040
# 3           The Attachment Diaries  743040
# 4           The Attachment Diaries  743040
# ...                            ...     ...
# 3244  Love in the Time of Fentanyl  976653
# 3245  Love in the Time of Fentanyl  976653
# 3246  Love in the Time of Fentanyl  976653
# 3247  Love in the Time of Fentanyl  976653
# 3248  Love in the Time of Fentanyl  976653
#
#                                   genres spoken_languages  \
# 0     [Drama, Mystery, Thriller, Horror]        [Spanish]
# 1     [Drama, Mystery, Thriller, Horror]        [Spanish]
# 2     [Drama, Mystery, Thriller, Horror]        [Spanish]
# 3     [Drama, Mystery, Thriller, Horror]        [Spanish]
# 4     [Drama, Mystery, Thriller, Horror]        [Spanish]
# ...                                  ...              ...
# 3244                       [Documentary]        [English]
# 3245                       [Documentary]        [English]
# 3246                       [Documentary]        [English]
# 3247                       [Documentary]        [English]
# 3248                       [Documentary]        [English]
#
#                     production_countries
# 0                            [Argentina]
# 1                            [Argentina]
# 2                            [Argentina]
# 3                            [Argentina]
# 4                            [Argentina]
# ...                                  ...
# 3244  [Canada, United States of America]
# 3245  [Canada, United States of America]
# 3246  [Canada, United States of America]
# 3247  [Canada, United States of America]
# 3248  [Canada, United States of America]
#
# [3249 rows x 21 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = merged_df[['genres', 'spoken_languages', 'production_countries']]

# Create a list of characters to remove
characters_to_remove = ['[', ']', "'"]

# Loop through the list of columns to fix
for column in columns_to_fix:

    # Convert the column to git atype 'str'
    merged_df[column] = merged_df[column].astype(str)

    # Loop through characters to remove
    for character in characters_to_remove:
    
        merged_df[column] = merged_df[column].str.replace(character, '')

# Display the fixed DataFrame
merged_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/25/movies/the-...
# 2  https://www.nytimes.com/2023/05/25/movies/the-...
# 3  https://www.nytimes.com/2023/05/25/movies/the-...
# 4  https://www.nytimes.com/2023/05/25/movies/the-...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  A gynecologist and her patient form a horrifyi...  The New York Times
# 2  A gynecologist and her patient form a horrifyi...  The New York Times
# 3  A gynecologist and her patient form a horrifyi...  The New York Times
# 4  A gynecologist and her patient form a horrifyi...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: The Attachment...
# 2  subject: Movies;creative_works: The Attachment...
# 3  subject: Movies;creative_works: The Attachment...
# 4  subject: Movies;creative_works: The Attachment...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-25T11:00:03+0000         295
# 2  2023-05-25T11:00:03+0000         295
# 3  2023-05-25T11:00:03+0000         295
# 4  2023-05-25T11:00:03+0000         295
#
#                                  headline.main headline.kicker  \
# 0  ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘The Attachment Diaries’ Review: Love, Sick            None
# 2  ‘The Attachment Diaries’ Review: Love, Sick            None
# 3  ‘The Attachment Diaries’ Review: Love, Sick            None
# 4  ‘The Attachment Diaries’ Review: Love, Sick            None
#
#   headline.content_kicker headline.print_headline  ... headline.seo  \
# 0                    None  The Attachment Diaries  ...         None
# 1                    None  The Attachment Diaries  ...         None
# 2                    None  The Attachment Diaries  ...         None
# 3                    None  The Attachment Diaries  ...         None
# 4                    None  The Attachment Diaries  ...         None
#
#   headline.sub         byline.original  \
# 0         None  By Jeannette Catsoulis
# 1         None  By Jeannette Catsoulis
# 2         None  By Jeannette Catsoulis
# 3         None  By Jeannette Catsoulis
# 4         None  By Jeannette Catsoulis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Jeannette', 'middlename': None...                None
# 3  [{'firstname': 'Jeannette', 'middlename': None...                None
# 4  [{'firstname': 'Jeannette', 'middlename': None...                None
#
#                     title      id                            genres  \
# 0  The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 1  The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 2  The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 3  The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 4  The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
#
#   spoken_languages production_countries
# 0          Spanish            Argentina
# 1          Spanish            Argentina
# 2          Spanish            Argentina
# 3          Spanish            Argentina
# 4          Spanish            Argentina
#
# [5 rows x 21 columns]

# %%
# Drop "byline.person" column
merged_df = merged_df.drop(columns=['byline.person'])

# %%
merged_df
# Out:
#                                                 web_url  \
# 0     https://www.nytimes.com/2023/05/25/movies/the-...
# 1     https://www.nytimes.com/2023/05/25/movies/the-...
# 2     https://www.nytimes.com/2023/05/25/movies/the-...
# 3     https://www.nytimes.com/2023/05/25/movies/the-...
# 4     https://www.nytimes.com/2023/05/25/movies/the-...
# ...                                                 ...
# 3244  https://www.nytimes.com/2023/02/02/movies/love...
# 3245  https://www.nytimes.com/2023/02/02/movies/love...
# 3246  https://www.nytimes.com/2023/02/02/movies/love...
# 3247  https://www.nytimes.com/2023/02/02/movies/love...
# 3248  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                 snippet              source  \
# 0     A gynecologist and her patient form a horrifyi...  The New York Times
# 1     A gynecologist and her patient form a horrifyi...  The New York Times
# 2     A gynecologist and her patient form a horrifyi...  The New York Times
# 3     A gynecologist and her patient form a horrifyi...  The New York Times
# 4     A gynecologist and her patient form a horrifyi...  The New York Times
# ...                                                 ...                 ...
# 3244  To combat the overdose crisis, a group that in...  The New York Times
# 3245  To combat the overdose crisis, a group that in...  The New York Times
# 3246  To combat the overdose crisis, a group that in...  The New York Times
# 3247  To combat the overdose crisis, a group that in...  The New York Times
# 3248  To combat the overdose crisis, a group that in...  The New York Times
#
#                                                keywords  \
# 0     subject: Movies;creative_works: The Attachment...
# 1     subject: Movies;creative_works: The Attachment...
# 2     subject: Movies;creative_works: The Attachment...
# 3     subject: Movies;creative_works: The Attachment...
# 4     subject: Movies;creative_works: The Attachment...
# ...                                                 ...
# 3244  subject: Documentary Films and Programs;subjec...
# 3245  subject: Documentary Films and Programs;subjec...
# 3246  subject: Documentary Films and Programs;subjec...
# 3247  subject: Documentary Films and Programs;subjec...
# 3248  subject: Documentary Films and Programs;subjec...
#
#                       pub_date  word_count  \
# 0     2023-05-25T11:00:03+0000         295
# 1     2023-05-25T11:00:03+0000         295
# 2     2023-05-25T11:00:03+0000         295
# 3     2023-05-25T11:00:03+0000         295
# 4     2023-05-25T11:00:03+0000         295
# ...                        ...         ...
# 3244  2023-02-02T12:00:11+0000         306
# 3245  2023-02-02T12:00:11+0000         306
# 3246  2023-02-02T12:00:11+0000         306
# 3247  2023-02-02T12:00:11+0000         306
# 3248  2023-02-02T12:00:11+0000         306
#
#                                           headline.main headline.kicker  \
# 0           ‘The Attachment Diaries’ Review: Love, Sick            None
# 1           ‘The Attachment Diaries’ Review: Love, Sick            None
# 2           ‘The Attachment Diaries’ Review: Love, Sick            None
# 3           ‘The Attachment Diaries’ Review: Love, Sick            None
# 4           ‘The Attachment Diaries’ Review: Love, Sick            None
# ...                                                 ...             ...
# 3244  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3245  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3246  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3247  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3248  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#      headline.content_kicker       headline.print_headline headline.name  \
# 0                       None        The Attachment Diaries          None
# 1                       None        The Attachment Diaries          None
# 2                       None        The Attachment Diaries          None
# 3                       None        The Attachment Diaries          None
# 4                       None        The Attachment Diaries          None
# ...                      ...                           ...           ...
# 3244                    None  Love in the Time Of Fentanyl          None
# 3245                    None  Love in the Time Of Fentanyl          None
# 3246                    None  Love in the Time Of Fentanyl          None
# 3247                    None  Love in the Time Of Fentanyl          None
# 3248                    None  Love in the Time Of Fentanyl          None
#
#      headline.seo headline.sub         byline.original byline.organization  \
# 0            None         None  By Jeannette Catsoulis                None
# 1            None         None  By Jeannette Catsoulis                None
# 2            None         None  By Jeannette Catsoulis                None
# 3            None         None  By Jeannette Catsoulis                None
# 4            None         None  By Jeannette Catsoulis                None
# ...           ...          ...                     ...                 ...
# 3244         None         None   By Concepción de León                None
# 3245         None         None   By Concepción de León                None
# 3246         None         None   By Concepción de León                None
# 3247         None         None   By Concepción de León                None
# 3248         None         None   By Concepción de León                None
#
#                              title      id                            genres  \
# 0           The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 1           The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 2           The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 3           The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 4           The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# ...                            ...     ...                               ...
# 3244  Love in the Time of Fentanyl  976653                       Documentary
# 3245  Love in the Time of Fentanyl  976653                       Documentary
# 3246  Love in the Time of Fentanyl  976653                       Documentary
# 3247  Love in the Time of Fentanyl  976653                       Documentary
# 3248  Love in the Time of Fentanyl  976653                       Documentary
#
#      spoken_languages              production_countries
# 0             Spanish                         Argentina
# 1             Spanish                         Argentina
# 2             Spanish                         Argentina
# 3             Spanish                         Argentina
# 4             Spanish                         Argentina
# ...               ...                               ...
# 3244          English  Canada, United States of America
# 3245          English  Canada, United States of America
# 3246          English  Canada, United States of America
# 3247          English  Canada, United States of America
# 3248          English  Canada, United States of America
#
# [3249 rows x 20 columns]

# %%
# Delete duplicate rows and reset index
merged_df.drop_duplicates
merged_df
# Out:
#                                                 web_url  \
# 0     https://www.nytimes.com/2023/05/25/movies/the-...
# 1     https://www.nytimes.com/2023/05/25/movies/the-...
# 2     https://www.nytimes.com/2023/05/25/movies/the-...
# 3     https://www.nytimes.com/2023/05/25/movies/the-...
# 4     https://www.nytimes.com/2023/05/25/movies/the-...
# ...                                                 ...
# 3244  https://www.nytimes.com/2023/02/02/movies/love...
# 3245  https://www.nytimes.com/2023/02/02/movies/love...
# 3246  https://www.nytimes.com/2023/02/02/movies/love...
# 3247  https://www.nytimes.com/2023/02/02/movies/love...
# 3248  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                 snippet              source  \
# 0     A gynecologist and her patient form a horrifyi...  The New York Times
# 1     A gynecologist and her patient form a horrifyi...  The New York Times
# 2     A gynecologist and her patient form a horrifyi...  The New York Times
# 3     A gynecologist and her patient form a horrifyi...  The New York Times
# 4     A gynecologist and her patient form a horrifyi...  The New York Times
# ...                                                 ...                 ...
# 3244  To combat the overdose crisis, a group that in...  The New York Times
# 3245  To combat the overdose crisis, a group that in...  The New York Times
# 3246  To combat the overdose crisis, a group that in...  The New York Times
# 3247  To combat the overdose crisis, a group that in...  The New York Times
# 3248  To combat the overdose crisis, a group that in...  The New York Times
#
#                                                keywords  \
# 0     subject: Movies;creative_works: The Attachment...
# 1     subject: Movies;creative_works: The Attachment...
# 2     subject: Movies;creative_works: The Attachment...
# 3     subject: Movies;creative_works: The Attachment...
# 4     subject: Movies;creative_works: The Attachment...
# ...                                                 ...
# 3244  subject: Documentary Films and Programs;subjec...
# 3245  subject: Documentary Films and Programs;subjec...
# 3246  subject: Documentary Films and Programs;subjec...
# 3247  subject: Documentary Films and Programs;subjec...
# 3248  subject: Documentary Films and Programs;subjec...
#
#                       pub_date  word_count  \
# 0     2023-05-25T11:00:03+0000         295
# 1     2023-05-25T11:00:03+0000         295
# 2     2023-05-25T11:00:03+0000         295
# 3     2023-05-25T11:00:03+0000         295
# 4     2023-05-25T11:00:03+0000         295
# ...                        ...         ...
# 3244  2023-02-02T12:00:11+0000         306
# 3245  2023-02-02T12:00:11+0000         306
# 3246  2023-02-02T12:00:11+0000         306
# 3247  2023-02-02T12:00:11+0000         306
# 3248  2023-02-02T12:00:11+0000         306
#
#                                           headline.main headline.kicker  \
# 0           ‘The Attachment Diaries’ Review: Love, Sick            None
# 1           ‘The Attachment Diaries’ Review: Love, Sick            None
# 2           ‘The Attachment Diaries’ Review: Love, Sick            None
# 3           ‘The Attachment Diaries’ Review: Love, Sick            None
# 4           ‘The Attachment Diaries’ Review: Love, Sick            None
# ...                                                 ...             ...
# 3244  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3245  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3246  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3247  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3248  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#      headline.content_kicker       headline.print_headline headline.name  \
# 0                       None        The Attachment Diaries          None
# 1                       None        The Attachment Diaries          None
# 2                       None        The Attachment Diaries          None
# 3                       None        The Attachment Diaries          None
# 4                       None        The Attachment Diaries          None
# ...                      ...                           ...           ...
# 3244                    None  Love in the Time Of Fentanyl          None
# 3245                    None  Love in the Time Of Fentanyl          None
# 3246                    None  Love in the Time Of Fentanyl          None
# 3247                    None  Love in the Time Of Fentanyl          None
# 3248                    None  Love in the Time Of Fentanyl          None
#
#      headline.seo headline.sub         byline.original byline.organization  \
# 0            None         None  By Jeannette Catsoulis                None
# 1            None         None  By Jeannette Catsoulis                None
# 2            None         None  By Jeannette Catsoulis                None
# 3            None         None  By Jeannette Catsoulis                None
# 4            None         None  By Jeannette Catsoulis                None
# ...           ...          ...                     ...                 ...
# 3244         None         None   By Concepción de León                None
# 3245         None         None   By Concepción de León                None
# 3246         None         None   By Concepción de León                None
# 3247         None         None   By Concepción de León                None
# 3248         None         None   By Concepción de León                None
#
#                              title      id                            genres  \
# 0           The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 1           The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 2           The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 3           The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 4           The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# ...                            ...     ...                               ...
# 3244  Love in the Time of Fentanyl  976653                       Documentary
# 3245  Love in the Time of Fentanyl  976653                       Documentary
# 3246  Love in the Time of Fentanyl  976653                       Documentary
# 3247  Love in the Time of Fentanyl  976653                       Documentary
# 3248  Love in the Time of Fentanyl  976653                       Documentary
#
#      spoken_languages              production_countries
# 0             Spanish                         Argentina
# 1             Spanish                         Argentina
# 2             Spanish                         Argentina
# 3             Spanish                         Argentina
# 4             Spanish                         Argentina
# ...               ...                               ...
# 3244          English  Canada, United States of America
# 3245          English  Canada, United States of America
# 3246          English  Canada, United States of America
# 3247          English  Canada, United States of America
# 3248          English  Canada, United States of America
#
# [3249 rows x 20 columns]

# %%
# Export data to CSV without the index
merged_df.to_csv

#Hurray!
# Out:
# <bound method NDFrame.to_csv of                                                 web_url  \
# 0     https://www.nytimes.com/2023/05/25/movies/the-...
# 1     https://www.nytimes.com/2023/05/25/movies/the-...
# 2     https://www.nytimes.com/2023/05/25/movies/the-...
# 3     https://www.nytimes.com/2023/05/25/movies/the-...
# 4     https://www.nytimes.com/2023/05/25/movies/the-...
# ...                                                 ...
# 3244  https://www.nytimes.com/2023/02/02/movies/love...
# 3245  https://www.nytimes.com/2023/02/02/movies/love...
# 3246  https://www.nytimes.com/2023/02/02/movies/love...
# 3247  https://www.nytimes.com/2023/02/02/movies/love...
# 3248  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                 snippet              source  \
# 0     A gynecologist and her patient form a horrifyi...  The New York Times
# 1     A gynecologist and her patient form a horrifyi...  The New York Times
# 2     A gynecologist and her patient form a horrifyi...  The New York Times
# 3     A gynecologist and her patient form a horrifyi...  The New York Times
# 4     A gynecologist and her patient form a horrifyi...  The New York Times
# ...                                                 ...                 ...
# 3244  To combat the overdose crisis, a group that in...  The New York Times
# 3245  To combat the overdose crisis, a group that in...  The New York Times
# 3246  To combat the overdose crisis, a group that in...  The New York Times
# 3247  To combat the overdose crisis, a group that in...  The New York Times
# 3248  To combat the overdose crisis, a group that in...  The New York Times
#
#                                                keywords  \
# 0     subject: Movies;creative_works: The Attachment...
# 1     subject: Movies;creative_works: The Attachment...
# 2     subject: Movies;creative_works: The Attachment...
# 3     subject: Movies;creative_works: The Attachment...
# 4     subject: Movies;creative_works: The Attachment...
# ...                                                 ...
# 3244  subject: Documentary Films and Programs;subjec...
# 3245  subject: Documentary Films and Programs;subjec...
# 3246  subject: Documentary Films and Programs;subjec...
# 3247  subject: Documentary Films and Programs;subjec...
# 3248  subject: Documentary Films and Programs;subjec...
#
#                       pub_date  word_count  \
# 0     2023-05-25T11:00:03+0000         295
# 1     2023-05-25T11:00:03+0000         295
# 2     2023-05-25T11:00:03+0000         295
# 3     2023-05-25T11:00:03+0000         295
# 4     2023-05-25T11:00:03+0000         295
# ...                        ...         ...
# 3244  2023-02-02T12:00:11+0000         306
# 3245  2023-02-02T12:00:11+0000         306
# 3246  2023-02-02T12:00:11+0000         306
# 3247  2023-02-02T12:00:11+0000         306
# 3248  2023-02-02T12:00:11+0000         306
#
#                                           headline.main headline.kicker  \
# 0           ‘The Attachment Diaries’ Review: Love, Sick            None
# 1           ‘The Attachment Diaries’ Review: Love, Sick            None
# 2           ‘The Attachment Diaries’ Review: Love, Sick            None
# 3           ‘The Attachment Diaries’ Review: Love, Sick            None
# 4           ‘The Attachment Diaries’ Review: Love, Sick            None
# ...                                                 ...             ...
# 3244  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3245  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3246  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3247  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 3248  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#      headline.content_kicker       headline.print_headline headline.name  \
# 0                       None        The Attachment Diaries          None
# 1                       None        The Attachment Diaries          None
# 2                       None        The Attachment Diaries          None
# 3                       None        The Attachment Diaries          None
# 4                       None        The Attachment Diaries          None
# ...                      ...                           ...           ...
# 3244                    None  Love in the Time Of Fentanyl          None
# 3245                    None  Love in the Time Of Fentanyl          None
# 3246                    None  Love in the Time Of Fentanyl          None
# 3247                    None  Love in the Time Of Fentanyl          None
# 3248                    None  Love in the Time Of Fentanyl          None
#
#      headline.seo headline.sub         byline.original byline.organization  \
# 0            None         None  By Jeannette Catsoulis                None
# 1            None         None  By Jeannette Catsoulis                None
# 2            None         None  By Jeannette Catsoulis                None
# 3            None         None  By Jeannette Catsoulis                None
# 4            None         None  By Jeannette Catsoulis                None
# ...           ...          ...                     ...                 ...
# 3244         None         None   By Concepción de León                None
# 3245         None         None   By Concepción de León                None
# 3246         None         None   By Concepción de León                None
# 3247         None         None   By Concepción de León                None
# 3248         None         None   By Concepción de León                None
#
#                              title      id                            genres  \
# 0           The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 1           The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 2           The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 3           The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 4           The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# ...                            ...     ...                               ...
# 3244  Love in the Time of Fentanyl  976653                       Documentary
# 3245  Love in the Time of Fentanyl  976653                       Documentary
# 3246  Love in the Time of Fentanyl  976653                       Documentary
# 3247  Love in the Time of Fentanyl  976653                       Documentary
# 3248  Love in the Time of Fentanyl  976653                       Documentary
#
#      spoken_languages              production_countries
# 0             Spanish                         Argentina
# 1             Spanish                         Argentina
# 2             Spanish                         Argentina
# 3             Spanish                         Argentina
# 4             Spanish                         Argentina
# ...               ...                               ...
# 3244          English  Canada, United States of America
# 3245          English  Canada, United States of America
# 3246          English  Canada, United States of America
# 3247          English  Canada, United States of America
# 3248          English  Canada, United States of America
#
# [3249 rows x 20 columns]>
